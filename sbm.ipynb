# %%
import matplotlib.pyplot as plt

from algorithms import *
from helper import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
N = 500
a = 5
b = 1 # d = 3, verifies inequality

x_star = generate_x(N)

# %%
x_hat_metropolis, overlap_hat_metropolis = run_experiment(N, a, b, x_star, metropolis, nb_iter=100, nb_exp=10)
# Out:
# 100%|██████████| 10/10 [07:51<00:00, 47.16s/it]

# %%
plt.plot(overlap_hat_metropolis)
plt.show()

# %%
# %%time
a = 0
for i in range(1_000_000):
    a += 1
    if a % 10 == 0:
        a *= 10
# Out:
# CPU times: user 1min 19s, sys: 0 ns, total: 1min 19s
# Wall time: 1min 19s
