# %%
import matplotlib.pyplot as plt

from algorithms import *
from helper import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
plt.rcParams["figure.figsize"] = (14, 10)

# %%
N = 1000
a = 5.9
b = 0.1 # d = 3, verifies inequality
nb_iters = 2000
nb_exp = 100

x_star = generate_x(N)

# %%
# %%time
N = 500
a = 5.9
b = 0.1
nb_iters = 35000
nb_exp = 100

x_star = generate_x(N)
overlap_hat_metropolis = run_experiment(N, a, b, x_star, metropolis, nb_iter=nb_iters, nb_exp=nb_exp)
# Out:
# 100%|██████████| 100/100 [03:22<00:00,  2.02s/it]
# CPU times: user 3min 21s, sys: 578 ms, total: 3min 22s
# Wall time: 3min 22s

# %%
visualise_overlap(overlap_hat_metropolis, nb_iters, nb_exp)

# %%
N = 100
nb_iters = 25000
nb_exp = 100
a = 5.9
b = 0.1
x_star = generate_x(N)
overlap_hat_houdayer = run_experiment(N, a, b, x_star, houdayer, nb_iter=nb_iters, nb_exp=nb_exp)
# Out:
# 100%|██████████| 100/100 [28:20<00:00, 17.01s/it]

# %%
visualise_overlap(overlap_hat_houdayer, nb_iters, nb_exp)

# %%
N = 100
nb_iters = 5000
nb_exp = 100
x_star = generate_x(N)
a = 5.9
b = 0.1
n0=10

overlap_hat_mixed = run_experiment(N, a, b, x_star, mixed_houdayer, nb_iter=nb_iters, nb_exp=nb_exp, n0=n0)
# Out:
# 100%|██████████| 100/100 [01:13<00:00,  1.36it/s]

# %%
visualise_overlap(overlap_hat_mixed, nb_iters, nb_exp)
